# %% [markdown]
# # 02 — Event study
#
# Load `data/processed/backtest/event_study_summary.parquet` and sort by `p_bootstrap`.

# %%
import polars as pl
from helios_alpha.config import load_settings

s = load_settings()
path = s.data_processed / "backtest" / "event_study_summary.parquet"
df = pl.read_parquet(path)
df.sort("p_bootstrap").head(20)
